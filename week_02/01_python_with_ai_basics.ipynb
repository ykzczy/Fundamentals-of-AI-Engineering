# %% [markdown]
# # Week 2 — Python With AI Basics
#
# Use this notebook to practice the small amount of Python needed before Week 3. For each section: run the code, ask an AI tool to explain it, make one small change, and run it again.

# %% [markdown]
# ## How To Use AI In This Notebook
#
# Prompt template:
#
# ```text
# I am learning Python as a beginner. Explain this code in simple terms.
# Then ask me one question to check my understanding.
#
# Code:
# [paste code cell]
# ```

# %% [markdown]
# ## 1. Variables And Strings

# %%
student_name = "Ada"
course_name = "AI Engineering"
message = student_name + " is learning " + course_name
print(message)

# %% [markdown]
# TODO: change `student_name` to your name and rerun the cell.

# %% [markdown]
# ## 2. Lists

# %%
scores = [80, 95, 72]
total = sum(scores)
average = total / len(scores)
print("average:", average)

# %% [markdown]
# TODO: add one more score and predict the new average before you run it.

# %% [markdown]
# ## 3. Dictionaries

# %%
profile = {
    "rows": 100,
    "columns": 5,
    "missing_values": 2,
}

print("Rows:", profile["rows"])
print("Columns:", profile["columns"])

# %% [markdown]
# TODO: add a new key called `dataset_name` and print it.

# %% [markdown]
# ## 4. Functions

# %%
def describe_column(column_name, missing_count):
    return column_name + " has " + str(missing_count) + " missing values"

print(describe_column("age", 3))

# %% [markdown]
# TODO: call the function with a different column name and missing count.

# %% [markdown]
# ## 5. Imports And Pandas Check

# %%
import pandas as pd

print("pandas version:", pd.__version__)

# %% [markdown]
# If this cell fails, copy the full error and ask an AI tool to help you check whether the notebook is using the right Python environment.

# %% [markdown]
# ## 6. Small DataFrame

# %%
data = pd.DataFrame(
    {
        "name": ["Ada", "Grace", "Katherine"],
        "score": [95, 88, 91],
    }
)

display(data)
print("rows:", data.shape[0])
print("columns:", data.shape[1])

# %% [markdown]
# TODO: add one more row to the DataFrame and verify the row count changes.
