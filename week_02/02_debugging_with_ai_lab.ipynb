# %% [markdown]
# # Week 2 — Debugging With AI Lab
#
# This notebook practices the same debugging habit you will use in scripts: run code, copy the full error, ask AI for the smallest fix, apply it, and rerun.

# %% [markdown]
# ## Debugging Prompt
#
# ```text
# I am debugging Python as a beginner.
#
# Goal:
# [what I tried to do]
#
# Full error or wrong output:
# [paste the full traceback or output]
#
# Please explain the issue, suggest the smallest fix, and tell me how to verify it.
# ```

# %% [markdown]
# ## 1. Syntax Error
#
# Run this cell. It should fail. Copy the full error into your AI tool.

# %%
# Fix this cell after reading the error.
code_with_error = """
def greet(name)
    return "Hello, " + name
"""

exec(code_with_error)

# %% [markdown]
# Verification: after fixing the code string, run `print(greet("Ada"))` and confirm it prints `Hello, Ada`.

# %%
# Run this after you fix the previous cell.
# print(greet("Ada"))

# %% [markdown]
# ## 2. Runtime Error
#
# Run this cell. It should fail because the data includes zero.

# %%
def divide_ten_by_each(numbers):
    results = []
    for number in numbers:
        results.append(10 / number)
    return results

print(divide_ten_by_each([5, 2, 0, 1]))

# %% [markdown]
# Verification: change the function so it handles zero clearly, then rerun it.

# %% [markdown]
# ## 3. Logic Error
#
# This cell runs, but the answer is wrong. Ask AI to help you reason from the expected output.

# %%
def is_greater_than_ten(value):
    return value < 10

print("Expected True, got:", is_greater_than_ten(15))
print("Expected False, got:", is_greater_than_ten(5))

# %% [markdown]
# Verification: fix the condition and rerun both checks.
